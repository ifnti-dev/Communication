# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import random
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
from datetime import datetime

# %%
chrome = webdriver.Chrome(ChromeDriverManager().install())
chrome.get("https://web.whatsapp.com")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 94.0.4606
# Get LATEST driver version for 94.0.4606
# Get LATEST driver version for 94.0.4606
# Trying to download new driver from https://chromedriver.storage.googleapis.com/94.0.4606.113/chromedriver_linux64.zip
# Driver has been saved in cache [/home/jean-christophe/.wdm/drivers/chromedriver/linux64/94.0.4606.113]

# %%
#Recherche le chemin passé en arument et le renvoie
#Si rien n'est trouvé avant le timeout, une exception est levée.
def chercher_element(chemin: str, timeout: int):
    trouve = False
    temps = 0
    while(not trouve):
        try: 
            element = chrome.find_element_by_xpath(chemin)
            trouve = True
        except: 
            time.sleep(0.5)
            temps += 0.5
        if(temps > timeout):
            raise Exception("Élément non trouvé pour le chemin : " + chemin) 
    return element

#Recherche tous les chemins passés en arument et renvoie le premier élément trouvé, ainsi que l'index du chemin auquel il correspond.
#Si rien n'est trouvé avant le timeout, une exception est levée.
#On n'utilise pas la fonction chercher_element afin de faire toutes les recherches en parallèle pour ne pas attendre les timeout à chaque fois.
def chercher_elements(chemins, timeout: int):
    trouve = False
    temps = 0
    element = None
    index = -1
    while(temps < timeout):
        for i in range(len(chemins)):
            try: 
                index = i
                element = chrome.find_element_by_xpath(chemins[i])
                trouve = True
                return (element, index)
            except:
                time.sleep(0.3)
                temps += 0.3
    raise Exception("Élément non trouvé pour les chemins : " + str(chemins))
    

def taper_message(tel: str, nom:str, prenom: str, message: str, num_contact: str, mots_cle_interdits = []):
    
    #taper le message dans le champ message
    #Le caractère '\n' est interprété comme un appui sur la touche "entrer". Ce qui envoie le message. On remplace tous les \n par une combinaison Shift + Enter
    search_box = chercher_element('/html/body/div[1]/div/div/div[4]/div/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[@class="_13NKt copyable-text selectable-text"][@contenteditable="true"][@dir="ltr"][@spellcheck="true"]', 3)
    
    
    for ligne in message.split('\n'):
        search_box.send_keys(ligne)
        ActionChains(chrome).key_down(Keys.SHIFT).key_down(Keys.ENTER).key_up(Keys.SHIFT).key_up(Keys.ENTER).perform()
    return True
    

#Envoie un message au numéro de téléphone passé en argument, si celui ci est trouvé.
#La chaine de la PJ doit être un chemin absolu vers un fichier présent en local sur l'ordinateur.
#Pour ne pas mettre de PJ, simplement passer une chaine vide, ou bien ne pas préciser cet argument.
#mots_cle_interdits est un tableau de chaines de caractère. S'il n'est pas vide, le message ne sera envoyé que si la conversation sélectionnée ne contient aucun des mots clé interdits. (permet d'éviter les messages en doublon, mais prend du temps)
def envoyer_message(tel: str, nom: str, prenom: str, message: str, image='', mots_cles_interdits = []):
    global statut_envoi
    
    #On commence par chercher si un des mots-clé interdits existe dans la conversation.
    time.sleep(1) #On laisse le temps à la conversation de se charger. Sinon, la recherche n'a pas accès aux anciens messages.
    try:
        doit_envoyer = True
        for mot_cle in mots_cles_interdits :
            if(chercher_contenu_dans_discussion(mot_cle)):
                doit_envoyer = False
                statut_envoi += " | le mot-clé interdit '" + mot_cle + "' a été trouvé -> pas d'envoi"
                return False
        if(doit_envoyer):
            statut_envoi += " | aucun des mots-clés interdits n'a été trouvé -> envoi"
            print(statut_envoi)
    except Exception as e:
        print(str(e))
        statut_envoi += " | exception lors de la recherche des mots-clés"
        print(statut_envoi)
        raise Exception("exception lors de la recherche des mots-clés")
    
    #Aucun des mots-clé interdits n'a été trouvé, on continue
    if(not taper_message(tel, nom, prenom, message, num_contact, mots_cles_interdits)):
        return False
    time.sleep(0.5)
    
    if(image == ""):
        bouton_envoyer = chercher_element("//button[span/@data-testid='send']", 1)
        bouton_envoyer.click()
    else:
        #cliquer sur le bouton joindre
        boutonJoindre = chercher_element("//div[@role='button'][@title='Joindre']", 1)
        boutonJoindre.click()

        #sélection du fichier à envoyer
        input_box = chrome.find_element_by_tag_name('input')
        input_box.send_keys(image)

        #Attendre que le fichier se charge
        bouton_envoyer = chercher_element("//div[@role='button'][span/@data-testid='send']", 35)
        time.sleep(1)
        bouton_envoyer.click()
    
    statut_envoi += "| envoyé"
    return True


#Recherche la chaine passée en argument dans l'historique des message du contact actuellement sélectionné.
#Renoie vrai si au moins un message contient la chaine, faux sinon.
def chercher_contenu_dans_discussion(contenu: str):
    global statut_envoi
    try:
        bouton_chercher = chercher_element('//div[@role="button"][@title="Recherche..."]', 2)
        bouton_chercher.click()
    except:
        print()
    try:
        champ_saisie = chercher_element('//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::*//div[@contenteditable="true"][@class="_13NKt copyable-text selectable-text"]', 3)
        champ_saisie.clear()
        time.sleep(0.25)
        champ_saisie.send_keys(contenu)
        time.sleep(0.5)
    except Exception as e:
        statut_envoi += " | echec de la sélection de la barre de recherche"
        print(statut_envoi)
        raise Exception("echec de la sélection de la barre de recherche : " + str(e)) 
    
    chemin_succes = '/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="' + contenu + '"]'
    chemin_succes2 ='//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "' + contenu + '")]'
    chemin_echec  = '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]'

    index = -1
    (resultat, index) = chercher_elements([chemin_succes, chemin_succes2, chemin_echec], 10)
    if(index == 0 or index == 1):
        statut_envoi += " | message vraiment trouvé"
        return True
    elif((index == 2)):
        statut_envoi += " | message vraiment non trouvé"
        return False
    else:
        statut_envoi += " | valeur index = " + str(index) + "non acceptée dans la recherche de message"
        return True
    champ_saisie.clear()

    #Si rien n'a été renvoyé à ce moment, c'est qu'il y a eu un problème -> Levée d'exception.
    statut_envoi += " | échec de la recherche"
    raise Exception("Échec de la recherche pour le contenu " + contenu) 


    
#Recherche, puis sélectionne le contact s'il est trouvé. S'il n'est pas trouvé, renvoie Faux
#Si le contact est trouvé, vérifie qu'aucun des messages passés ne contient un des mot_clés interdits (pour éviter les envois en doublon)
#Au final, ne renvoie vrai que si le contact a été correctement sélectionné et qu'il faut envoyer le message.
def selectionner_contact(tel: str, nom: str, prenom: str, num_contact: str, mots_cles_interdits = []):
    global statut_envoi
    #On commence par cliquer sur le bouton pour annuler la recherche précédente
    try:
        bouton_annuler_recherche = chrome.find_element_by_xpath('//div[@class="_3yWey XKmj6"]//button[@class="_3GYfN"]')
        bouton_annuler_recherche.click()
        #print("recherche annulée avec succès !")
        time.sleep(0.5)
    except Exception as e:
        print(str(e))
    #On recherche le champ de saisie de la recherche de contact, pour y taper le numéro de téléphone.
    try:
        search_box = chrome.find_element_by_xpath('/html/body/div[1]/div/div/div[3]/div/div[1]/div/div/div[2]/div/div[@class="_13NKt copyable-text selectable-text"][@contenteditable="true"][@data-tab="3"][@dir="ltr"][not(@spellcheck)][@title="Champ de recherche"][@role="textbox"]')
        search_box.clear()
        search_box.send_keys(tel)
    except Exception as e:
        print(str(e))
    time.sleep(0.5)
    #Xpath1 ne comporte pas nativement de méthode pour passer en casse majuscule. On fait ça à la main.
    #Maintenant qu'on a tapé le numéro de téléphone dans le champ de recherche, on cherche si un titre de conversation apparaît
    #Si le message "Aucun contact, discussion ou message trouvé" apparaît, cela signifie que cette personne n'a pas whatsapp.
    try:
        titre_UpCass = 'translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ")'
        #chaine_chemin_contact = '//div[@aria-label="Résultats de la recherche."]/div[//span[contains(' + titre_UpCass + ',"{0}") or contains(' + titre_UpCass + ',"{1}")]]'
        chaine_chemin_contact = '//div[@aria-label="Résultats de la recherche."]/*[//*[contains(' + titre_UpCass + ',"{0}") or contains(' + titre_UpCass + ',"{1}")]]'
        chaine_chemin_contact2 = '//div[@aria-label="Résultats de la recherche."]/div/div[//span[contains(' + titre_UpCass + ',"{0}") or contains(' + titre_UpCass + ',"{1}")]]'
        chaine_chemin_contact3 = '//div[@aria-label="Résultats de la recherche."]/div/div/div[//span[contains(' + titre_UpCass + ',"{0}") or contains(' + titre_UpCass + ',"{1}")]]'
        chaine_chemin_contact4 = '//div[@aria-label="Résultats de la recherche."]/div/div/div/div[//span[contains(' + titre_UpCass + ',"{0}") or contains(' + titre_UpCass + ',"{1}")]]'
        
        xpath_contact_trouve = chaine_chemin_contact.format(nom.upper(), prenom.upper())
        xpath_contact_trouve2 = chaine_chemin_contact2.format(nom.upper(), prenom.upper())
        xpath_contact_trouve3 = chaine_chemin_contact3.format(nom.upper(), prenom.upper())
        xpath_contact_trouve4 = chaine_chemin_contact4.format(nom.upper(), prenom.upper())
        xpath_contact_non_trouve = '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]'
    except Exception as e:
        print(str(e))
    print(0)
    try:
        index = -1
        (bouton_contact, index) = chercher_elements([xpath_contact_trouve, xpath_contact_non_trouve], 3)
        print(1)
        if(index == 1):
            statut_envoi += " | Contact officiellement non trouvé"
            print("contact officiellement non trouvé")
            raise Exception("contact officiellement non trouvé")
        elif((index == -1)):
            statut_envoi += "échec de la recherche du contact"
            print("échec de la recherche du contact")
            raise Exception("échec de la recherche du contact")
        print(2)
        try:
            xpath_contact_trouves = [chaine_chemin_contact.format(nom.upper(), prenom.upper()),
                                     chaine_chemin_contact2.format(nom.upper(), prenom.upper()),
                                     chaine_chemin_contact3.format(nom.upper(), prenom.upper()),
                                     chaine_chemin_contact4.format(nom.upper(), prenom.upper())]
            bouton_contacts = [chercher_element(xpath_contact_trouve, 1),
                              chercher_element(xpath_contact_trouve2, 1),
                              chercher_element(xpath_contact_trouve3, 1),
                              chercher_element(xpath_contact_trouve4, 1)]

        except Exception as e:
            print("erreur lors de la recherche des boutons alternatifs : " + str(e))
        print(3)
        #Il semble que l'élément cliquable ne soit pas le même d'une conversation à l'autre. Je clique donc sur tout ce que je peux en espérant trouver le bon.
        temps_max = 3
        temps = 0       
        trouve = False
        
        prenom = prenom.upper().replace(" ", "").replace("-", "").replace("'", "")
        nom = nom.upper().replace(" ", "").replace("-", "").replace("'", "")
        print(4)
        while(not(trouve) and (temps < temps_max)):
            print("dans le while recherche de la conversation")
            for num_bouton in range(len(bouton_contacts)):
                try:
                    print("click sur le bouton " + str(num_bouton) + "   temps = " + str(temps))
                    bouton_contacts[num_bouton].click()
                    time.sleep(0.5)
                    Titre_conversation = chercher_element("//header/div/div/div/span[@dir='auto']", 4).text
                    Titre_conversation = Titre_conversation.upper().replace(" ", "").replace("-", "").replace("'", "")
                    trouve = (prenom in Titre_conversation) or (nom in Titre_conversation) or (str(tel) in Titre_conversation) or (("N" + num_contact) in Titre_conversation)
                    print("Titre_conversation" + Titre_conversation)
                    print("prenom : " + prenom)
                    print("prenom in Titre_conversation : " + str(prenom in Titre_conversation))
                    print("nom : " + nom)
                    print("nom in Titre_conversation : " + str(nom in Titre_conversation))
                    print("tel : " + str(tel))
                    print("str(tel) in Titre_conversation)" + str(str(tel) in Titre_conversation))
                    print("('N' + num_contact) in Titre_conversation : " + str((("N" + num_contact) in Titre_conversation)))
                    if(trouve):
                        print("Le titre correspond !")
                        break #On sort de la boucle for et le while va sortir en même temps.
                except Exception as e:
                    print(str(e))
            temps = temps + 1
        #print("après le while trouvé = " + str(trouve))
        print(5)
        search_box.clear()
        statut_envoi += " | contact trouvé 0"
        
        Titre_conversation = chercher_element("//header/div/div/div/span[@dir='auto']", 4).text

        print("Titre conversation : " + Titre_conversation)
        statut_envoi += " | 2"
        Titre_conversation = Titre_conversation.upper().replace(" ", "").replace("-", "").replace("'", "")
        statut_envoi += " | 2.1"
        if((prenom in Titre_conversation) or (nom in Titre_conversation) or (tel in Titre_conversation) or (("N" + num_contact) in Titre_conversation)):
            statut_envoi += " | contact sélectionné"
        else:
            print("Mauvais titre")
            statut_envoi += " | mais mauvais titre : '" + nom + " " + prenom + "' titre conversation : '" + Titre_conversation + "'"
            print(statut_envoi)
            raise Exception("mauvais titre : '" + nom + " " + prenom + "' titre conversation : '" + Titre_conversation + "'")

    except Exception as e:
        print(str(e))
        statut_envoi += " | Contact non trouvé"
        print(statut_envoi)
        raise Exception("Contact non trouvé")

    
    
def generer_message(prenom, nom, lycee, ville, annee):
    if(lycee != ""):
        lycee = "au lycée " + lycee
    else : 
        lycee = "dans ton lycée"
        
    #message = "Bonjour {0} {1},\n\n" + \
    #          "J'espère que tout s'e"
    #message = message.format(prenom, nom, lycee, ville)
        
    if(annee == "2020"):
        message = "Bonjour {0} {1},\n\n" + \
                  "Le premier concours d'entrée à l'IFNTI aura lieu *ce mercredi 29 juin*. Il ne reste que quelques jours pour s'inscrire.\n\n" + \
                  "Il y aura une autre session après les résultats du BAC. Mais ce sera plus difficile car il restera moins de places disponibles...\n\n" + \
                  "Cliquer ici pour s'inscrire : *https://forms.gle/9Cvqz7qpobzFgQuN7*"
        
        message = message.format(prenom, nom)
        
    elif(annee == "2021"):
        message = "Bonjour {0} {1},\n\n" + \
                  "Le premier concours d'entrée à l'IFNTI aura lieu *ce mercredi 29 juin*. Il ne reste que quelques jours pour s'inscrire.\n\n" + \
                  "Il y aura une autre session après les résultats du BAC. Mais ce sera plus difficile car il restera moins de places disponibles...\n\n" + \
                  "Cliquer ici pour s'inscrire : *https://forms.gle/9Cvqz7qpobzFgQuN7*"
        message = message.format(prenom, nom, lycee, ville)
        
    elif(annee == "2022"):
        message = "Bonjour {0} {1},\n\n" + \
                  "J'espère que tout s'est bien passé pour les épreuves du BAC2.\n\n" + \
                  "Le premier concours d'entrée à l'IFNTI aura lieu *ce mercredi 29 juin*. Il ne reste que quelques jours pour s'inscrire.\n\n" + \
                  "Il y aura une autre session après les résultats du BAC. Mais ce sera plus difficile car il restera moins de places disponibles...\n\n" + \
                  "Cliquer ici pour s'inscrire : *https://forms.gle/9Cvqz7qpobzFgQuN7*"
        message = message.format(prenom, nom, lycee, ville)
    else:
        print("erreur : étudiant avec année différent de 2020, 2021 ou 2022 : '" + str(annee) +"'")
        message = ""
    return message


statut_envoi = ""
fichier_etudiants = '/home/jean-christophe/git_IFNTI/Documentations_outils/envoi_whatsapp_supbot/liste_etudiants_interesses.csv'
fichier_log = '/home/jean-christophe/git_IFNTI/Documentations_outils/envoi_whatsapp_supbot/log_envoi.csv'
with open(fichier_etudiants, "r") as filin:
    with open(fichier_log, 'a') as filout:
        num_contact_envoye = 0
        for ligne in filin:
            statut_envoi = ""
            ligne = ligne.split(",")
            num_contact = ligne[0].replace("\n", "")
            ville = ligne[1].replace("\n", "")
            lycee = ligne[2].replace("\n", "")
            nom = ligne[3].replace("\n", "")
            prenom = ligne[4].replace("\n", "")
            prefixe_tel = ligne[5].replace("\n", "")
            tel = ligne[6].replace("-", "").replace("\n", "")
            tel2 = ligne[7].replace("-", "").replace("\n", "")
            annee = ligne[9].replace("\n", "")

            
            
            piece_jointe = ""
            #piece_jointe = "/home/jean-christophe/git_IFNTI/Administration/Outils_de_com/Videos/Presentation_IFNTI_juin_2021/Presentation_IFNTI_juin_2021_VLQ.mp4"
            #piece_jointe = "/home/jean-christophe/Images/vidage_telephone/2022/05-mai/20220521_130250.jpg"
            #piece_jointe = ""
            now = datetime.now().strftime("%d/%m/%Y,%H:%M:%S")
            
            #Pour ne pas mettre de pièce jointe, simplement mettre une chaine vide
            for num_tel in {tel, tel2}:
                if(num_tel != ""):
                    print(num_tel)
                    statut_envoi = ""
                    try:
                        selectionner_contact(num_tel, nom, prenom, num_contact)
                        message0 = generer_message(prenom, nom, lycee, ville, annee)
                        envoyer_message(num_tel, nom, prenom, message0, piece_jointe, ["Le premier concours d'entrée"])
                        message1 = "Vous cherchez une formation supérieure en informatique ? Découvrez l'IFNTI à Sokodé !\n\n" + \
                                  "*Présentation générale*\n" + \
                                  "L'objectif de l'Institut de Formation aux Normes et Technologies de l'Informatique est de faire en sorte que les étudiants togolais et plus particulièrement de la région centrale puissent bénéficier à moindre coût d'une formation supérieure en informatique, au standard international. Installé à Sokodé au cœur du Togo, l'IFNTI recrute les bacheliers scientifiques pour une licence professionnelle LMD en 3 ans.\n" + \
                                  "L'IFNTI est situé entre le lycée Technique et le lycée Moderne, dans le quartier administratif.\n\n" + \
                                  "*Conditions d'enseignement*\n" + \
                                  "La qualité de la formation est liée au taux d‘encadrement, avec de petits effectifs (promotions de 24 étudiants), et aux enseignants permanents de niveau ingénieur. Ceux-ci sont toujours disponibles pour soutenir les apprenants. Les modalités didactiques employées sont très proches de l’activité professionnelle. Depuis l'ouverture de l'IFNTI en 2014, tous les diplômés travaillent.\n\n" + \
                                  "*Candidature à l'IFNTI*\n" + \
                                  "Les promotions étant limitées à 24 étudiants, l'entrée à l'IFNTI se fait sur concours." + \
                                  "L'inscription se fait en ligne, en remplissant ce formulaire : https://forms.gle/9Cvqz7qpobzFgQuN7\n" + \
                                  "Il se déroule en deux étapes :\n" + \
                                  " - des épreuves écrites pendant une journée.\n" + \
                                  " - un entretien oral, conditionné par la réussite des épreuves écrites.\n" + \
                                  "Les deux étapes se dérouleront dans nos locaux à Sokodé.\n" + \
                                  "Vous serez évalués sur trois matières :\n" + \
                                  "- Français\n" + \
                                  "- Anglais\n" + \
                                  "- Mathématiques\n" + \
                                  "Frais d'inscription au concours : 10.000 FCFA.\n" + \
                                  "Date du premier *concours : 29 juin*. Une autre session du concours aura lieu après les résultats du bac2.\n\n" + \
                                  "*Inscription académique*\n" + \
                                  "Si vous êtes retenus après les épreuves orales, vous pourrez commencer la procédure d'inscription académique.\n" + \
                                  "Frais de scolarité : 590.000 FCFA / an.\n" + \
                                  "Frais d'inscription : 30.000 FCFA / an.\n" + \
                                  "Ces frais restent les mêmes pendant toute la formation. Les frais d'inscription ne sont pas remboursables.\n\n" + \
                                  "*Hébergement*\n" + \
                                  "L'IFNTI ne dispose pas de logements propres. Toutefois il est très facile de trouver un logement à Sokodé, et à un faible coût.\n\n" + \
                                  "Site internet\n" + \
                                  "https://www.ifnti.com\n\n" + \
                                  "Whatsapp\n" + \
                                  "+228 90 91 81 41\n\n" + \
                                  "Email\n" + \
                                  "contact@ifnti.com\n\n" + \
                                  "Vidéo de présentation\n" + \
                                  "https://www.youtube.com/watch?v=oDosebpBEf8"
                        #envoyer_message(num_tel, nom, prenom, message1, piece_jointe, ["Vous cherchez une formation"])
                        #message2 = "Voici la vidéo de présentation de l'IFNTI."
                        #piece_jointe = "/home/jean-christophe/git_IFNTI/Administration/Outils_de_com/Videos/Presentation_IFNTI_juin_2021/Presentation_IFNTI_juin_2021_VLQ.mp4"
                        #envoyer_message(num_tel, nom, prenom, message2, piece_jointe, ["Voici la vidéo de"])
                        print("\n\n\n")
                    except Exception as e:
                        print(str(e))
                    filout.write(now + "," + num_contact + "," + ville + "," + lycee + "," + nom + "," + prenom + "," + prefixe_tel + "," + num_tel + ",,," + annee + "," + statut_envoi + ",\n")
                    #Le fichier de Log a été organisé en suivant la structure du fichier liste_etudiants_intéresses.csv, de façon à pouvoir relancer le script sur tous ceux pour qui l'envoi a échoué afin de tenter une deuième fois.
                        
filout.close() 
filin.close()
print("Terminé.")
# Out:
# 79532705
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class="_3yWey XKmj6"]//button[@class="_3GYfN"]"}
#   (Session info: chrome=94.0.4606.81)
#
# 0
# 1
# contact officiellement non trouvé
# contact officiellement non trouvé
#  | Contact officiellement non trouvé | Contact non trouvé
# Contact non trouvé
# 70309293
# 0
# 1
# contact officiellement non trouvé
# contact officiellement non trouvé
#  | Contact officiellement non trouvé | Contact non trouvé
# Contact non trouvé
# 93939252
# 0
# 1
# contact officiellement non trouvé
# contact officiellement non trouvé
#  | Contact officiellement non trouvé | Contact non trouvé
# Contact non trouvé
# 70729491
# 0
# 1
# contact officiellement non trouvé
# contact officiellement non trouvé
#  | Contact officiellement non trouvé | Contact non trouvé
# Contact non trouvé
# 92704283
# 0
# 1
# contact officiellement non trouvé
# contact officiellement non trouvé
#  | Contact officiellement non trouvé | Contact non trouvé
# Contact non trouvé
# 92973127
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationGBANDIKOUDJOHOU,2022N2018
# prenom : GBANDI
# prenom in Titre_conversation : True
# nom : KOUDJOHOU
# nom in Titre_conversation : True
# tel : 92973127
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : GBANDI KOUDJOHOU, 2022 N2018
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 90747815
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationMABROUKADAGOLODJO,2022N2019
# prenom : MABROUK
# prenom in Titre_conversation : True
# nom : ADAGOLODJO
# nom in Titre_conversation : True
# tel : 90747815
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : MABROUK ADAGOLODJO, 2022 N2019
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 70530383
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationNIKABOUGNANDI,2022N2020
# prenom : NIKABOU
# prenom in Titre_conversation : True
# nom : GNANDI
# nom in Titre_conversation : True
# tel : 70530383
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : NIKABOU GNANDI, 2022 N2020
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 91262644
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationBAMAKOHOTAMA,2022N2021
# prenom : BAMAKO
# prenom in Titre_conversation : True
# nom : HOTAMA
# nom in Titre_conversation : True
# tel : 91262644
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : BAMAKO HOTAMA, 2022 N2021
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 93406326
# 0
# 1
# contact officiellement non trouvé
# contact officiellement non trouvé
#  | Contact officiellement non trouvé | Contact non trouvé
# Contact non trouvé
# 90170911
# 0
# 1
# contact officiellement non trouvé
# contact officiellement non trouvé
#  | Contact officiellement non trouvé | Contact non trouvé
# Contact non trouvé
# 91919213
# 0
# 1
# contact officiellement non trouvé
# contact officiellement non trouvé
#  | Contact officiellement non trouvé | Contact non trouvé
# Contact non trouvé
# 92347682
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationKPANTEWAGBE,2022N2024
# prenom : KPANTE
# prenom in Titre_conversation : True
# nom : WAGBE
# nom in Titre_conversation : True
# tel : 92347682
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : KPANTE WAGBE, 2022 N2024
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 93846348
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationGBATIDJATENE,2022N2025
# prenom : GBATI
# prenom in Titre_conversation : True
# nom : DJATENE
# nom in Titre_conversation : True
# tel : 93846348
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : GBATI DJATENE, 2022 N2025
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 91591632
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationRAKIBOUTCHANDIKOU,2022N2026
# prenom : RAKIBOU
# prenom in Titre_conversation : True
# nom : TCHANDIKOU
# nom in Titre_conversation : True
# tel : 91591632
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : RAKIBOU TCHANDIKOU, 2022 N2026
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 92323677
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationABASSELAMBONI,2022N2027
# prenom : ABASSE
# prenom in Titre_conversation : True
# nom : LAMBONI
# nom in Titre_conversation : True
# tel : 92323677
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : ABASSE LAMBONI, 2022 N2027
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 92253061
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationYAHYAESSOFA,2022N2028
# prenom : YAHYA
# prenom in Titre_conversation : True
# nom : ESSOFA
# nom in Titre_conversation : True
# tel : 92253061
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : YAHYA ESSOFA, 2022 N2028
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 91595751
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationKIDISSELESOUBOR,2022N2029
# prenom : KIDISSELE
# prenom in Titre_conversation : True
# nom : SOUBOR
# nom in Titre_conversation : True
# tel : 91595751
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : KIDISSELE SOUBOR, 2022 N2029
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 70378914
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationSAYIAKPO,2022N2030
# prenom : SAYI
# prenom in Titre_conversation : True
# nom : AKPO
# nom in Titre_conversation : True
# tel : 70378914
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : SAYI AKPO, 2022 N2030
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 93452668
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationBITEBENIKABOU,2022N2031
# prenom : BITEBE
# prenom in Titre_conversation : True
# nom : NIKABOU
# nom in Titre_conversation : True
# tel : 93452668
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Titre conversation : BITEBE NIKABOU, 2022 N2031
# Élément non trouvé pour les chemins : ['/html/body/div[1]/div/div/div[2]/div[3]/span/div/div/div[2]/div[1]/div/div/div/div/div/div[2]/div[2]/div[1]/span/span/strong[@class="i0jNr"][text()="Le premier concours d\'entrée"]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div//div[@class="_3uIPm WYyr1"]/div[@class="_3m_Xw"]/div/div/div/div/div/span[@class="Hy9nV"][contains(@title, "Le premier concours d\'entrée")]', '//header[//*[contains(text(),"Rechercher des messages")]]/following-sibling::div[@id="pane-side"]/div/div/span[@dir="auto"][@class="i0jNr"][text()="Aucun message trouvé"]']
#  | contact trouvé 0 | 2 | 2.1 | contact sélectionné | exception lors de la recherche des mots-clés
# exception lors de la recherche des mots-clés
# 91169008
# 0
# 1
# contact officiellement non trouvé
# contact officiellement non trouvé
#  | Contact officiellement non trouvé | Contact non trouvé
# Contact non trouvé
# 91963486
# 0
# 1
# 2
# 3
# 4
# dans le while recherche de la conversation
# click sur le bouton 0   temps = 0
# Titre_conversationPONABIRNATCHIPON,2022N2033
# prenom : PONABIR
# prenom in Titre_conversation : True
# nom : NATCHIPON
# nom in Titre_conversation : True
# tel : 91963486
# str(tel) in Titre_conversation)False
# ('N' + num_contact) in Titre_conversation : True
# Le titre correspond !
# 5
# Élément non trouvé pour le chemin : //header/div/div/div/span[@dir='auto']
#  | contact trouvé 0 | Contact non trouvé
# Contact non trouvé
# 92921080
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"GNENI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ABDEL QUAHAR")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93925747
# Message: invalid session id
#
# Message: invalid session id
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"WAGBE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NIKABAU JEAN")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 98470142
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ASSEWLELOU") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KADO")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70539120
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"SANTA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KOMIVI")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 92392665
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"LEMOU") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"MAMOUERE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 92924595
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NAKOUDJA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"RAÏME")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70853765
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KAGMAN") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"TCHIKAKPA FAURE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91154315
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NADJA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ADEH")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 92465127
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BIMBON") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"SUNSAYE ESTHER")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 92184537
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"GBARRE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BADA DESIRE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 90976394
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"GBARRE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BADA DESIRE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91888456
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"TIGHANABA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BOUKAR DONNE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 92262444
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ISSA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"MAMADOU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93082963
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"TOBILO") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"M\'PETROU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 92390183
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"AGOULOU") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"AMBALI")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 90205073
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BOUKARI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"RAFIOU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91801653
# Message: invalid session id
#
# Message: invalid session id
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"SOULEMANE-M") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"AFIZOU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91078332
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BDOU6RAHAMANE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"MOUSSTAFA")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 79532705
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KPATCHINE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"TAKOUFAM")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70309293
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KPANGHERI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"MAYENE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93939252
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KOUNA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ACHIRAF")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70729491
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"LABI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"LEONTINE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 92704283
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"OULIGUI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"N\'NANDAM")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93406326
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NAKOUDJA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"GNANKIDJI")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 90170911
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BAGMARE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"N\'DIGHOUBE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91919213
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"WAGBE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KPANTE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91169008
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"IREOU") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ESSODEWA")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 98470142
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ASSEWLELOU") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KADO")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70539120
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"SANTA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KOMIVI")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 92392665
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"LEMOU") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"MAMOUERE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91154315
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NADJA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ADEH")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 90976394
# Message: invalid session id
#
# Message: invalid session id
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"GBARRE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BADA DESIRE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93082963
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"TOBILO") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"M\'PETROU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 925954522
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"WAKE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"GBATI KADER")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93282120
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ALASSANI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"SALIHA")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 92262269
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"TALE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"SANGBO PASCAL")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93923441
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ALADOODJA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BARIYATOU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91496716
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BAMOLE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BINKONE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93368440
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ALBARKA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ILIGHAIN")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91645087
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NADJA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"LABANTE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91158954
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NADJOMBE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"SASSILE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93706745
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NADJOMBE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"SASSILE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70524050
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"IDRISSOU") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"RAZAK")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91580445
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KPAL") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"SOULEY")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91550113
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BIGHOULGMAPOU") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NIKABOU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70348325
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KOLANI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KOKOU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 97198411
# Message: invalid session id
#
# Message: invalid session id
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NIPADA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BACHIROU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 92383061
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"TOBTCHE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"HIMONXIME")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70047275
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"WADJA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"MATHIAS")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 98859405
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"WADJA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"MATHIAS")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93724111
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KOMBATE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"IKIMATOU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 90172815
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KPAL") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"YAOWAÏ")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 98586153
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KPAL") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"YAOWAÏ")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 90703728
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KPANTE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ESPOIR")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91060641
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"DJEIN") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NAPO BABAWAYE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91801404
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ANTANTE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"Y.DANIEL")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93421001
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# ...
#  | Contact non trouvé
# Contact non trouvé
# 70680840
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"LACBAYO") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"M. MÉRITE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 4386386046
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ALIZIOU") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ANGE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 97284724
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"AKPO") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"NANDJA")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 92323264
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"PANIZI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"DAVID")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70369038
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"AMIDIA")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93329190
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"PRISCA")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 79550613
# Message: invalid session id
#
# Message: invalid session id
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BIKILI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"MATÉROU CHRISTOPHE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 98942052
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KAMALA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KIBALO")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70859784
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KONTE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"FONMA")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70178863
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KOLOU") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"AMIDATOU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70831613
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KAOYAOU") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ESSOASSINAME")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70154904
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"AGBESSO") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"SAMSON")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91031117
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BALOUKI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"GEORGES")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70047871
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"LEKA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"GNATI-NLABA")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91761825
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KADJA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KOUMÉABALO")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91842067
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"HASSIKPESSI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ESSOHAMDEOU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 91583238
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KAYA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"MOHAHESSOU")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93269209
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ADINESSI") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"KOKOU ATTA")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 96981530
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"BARA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"DIEU-DONNE")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 90131974
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"EDJARE") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"AZIA")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 70441718
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"AKAYA") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"PYABALO")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93107626
# Message: invalid session id
#
# Message: invalid session id
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"PELEÏ") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"A. EDOUARD")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93983654
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# Élément non trouvé pour les chemins : ['//div[@aria-label="Résultats de la recherche."]/*[//*[contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"AWESSO") or contains(translate(@title,"abcdefghijklmnopqrstuvwxyzèéêëïîäâàüûùöô","ABCDEFGHIJKLMNOPQRSTUVWXYZÈÉÊËÏÎÄÂÀÜÛÙÖÔ"),"ESSONIWA JOSEPH")]]', '//span[@dir="auto"][@class="i0jNr"][contains(text(),"Aucun contact, discussion ou message trouvé")]']
#  | Contact non trouvé
# Contact non trouvé
# 93131244
# Message: invalid session id
#
# Message: invalid session id
#
# 0
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# <ipython-input-44-a52acec3d724> in chercher_elements(chemins, timeout)
#      28                 index = i
# ---> 29                 element = chrome.find_element_by_xpath(chemins[i])
#      30                 trouve = True
#
# ~/git_IFNTI/Documentations_outils/envoi_whatsapp_supbot/selenium_chrome/environment/whatsapp_env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# ~/git_IFNTI/Documentations_outils/envoi_whatsapp_supbot/selenium_chrome/environment/whatsapp_env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~/git_IFNTI/Documentations_outils/envoi_whatsapp_supbot/selenium_chrome/environment/whatsapp_env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~/git_IFNTI/Documentations_outils/envoi_whatsapp_supbot/selenium_chrome/environment/whatsapp_env/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# InvalidSessionIdException: Message: invalid session id
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-a52acec3d724> in <module>
#     339                     statut_envoi = ""
#     340                     try:
# --> 341                         selectionner_contact(num_tel, nom, prenom, num_contact)
#     342                         message0 = generer_message(prenom, nom, lycee, ville, annee)
#     343                         envoyer_message(num_tel, nom, prenom, message0, piece_jointe, ["Le premier concours d'entrée"])
#
# <ipython-input-44-a52acec3d724> in selectionner_contact(tel, nom, prenom, num_contact, mots_cles_interdits)
#     185     try:
#     186         index = -1
# --> 187         (bouton_contact, index) = chercher_elements([xpath_contact_trouve, xpath_contact_non_trouve], 3)
#     188         print(1)
#     189         if(index == 1):
#
# <ipython-input-44-a52acec3d724> in chercher_elements(chemins, timeout)
#      31                 return (element, index)
#      32             except:
# ---> 33                 time.sleep(0.3)
#      34                 temps += 0.3
#      35     raise Exception("Élément non trouvé pour les chemins : " + str(chemins))
#
# KeyboardInterrupt:
